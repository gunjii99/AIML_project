# %%
#This file applies the trained model to the data which conatains only the data from Starbucks, McDonald's and Dunkin'

import joblib
import import_ipynb
import Train_Test_split as ts
import json
# Out:
# <string>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Training data shape: (428988, 3)
# Test data shape: (107247, 3)
# Training samples: 343190, Validation samples: 85798, Test samples: 107247

# %%
# Load the vectorizer and model
vectorizer = joblib.load('tfidf_vectorizer.joblib')
model = joblib.load('logreg_bow_model.joblib')

# %%
# Example: Transform new data and predict
X_new_vec = vectorizer.transform(ts.BI_df['text'])
y_new_pred = model.predict(X_new_vec)

# %%
X_new_vec
# Out:
# <50426x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1709902 stored elements in Compressed Sparse Row format>

# %%
y_new_pred
# Out:
# array([1, 1, 3, ..., 1, 3, 3], dtype=int64)

# %%
ts.BI_df["bow_predicted_sentiment"] = y_new_pred
ts.BI_df
# Out:
# C:\Users\gunja\AppData\Local\Temp\ipykernel_25252\2073490316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts.BI_df["bow_predicted_sentiment"] = y_new_pred
#                        user_id             business_id  stars  useful  funny  \
# 31      veBX5roHQLNnQ1rTtNh_gg  aJvxWyQIG5OLfBw3qAe8xA      2       0      0
# 45      xUhG4eI0M1KRvucUn0t19w  QSA-x2bb3kum9QLFpy7vUg      2       0      0
# 46      zZygOZLNyJX5nDqKrwa4HQ  MjZQqZAmJeMco_Vq-Y9h-g      4       0      0
# 54      0SpK7eVn5TrpyQKPaohVBw  u7MJKcNdZXYyTeb67vD5jw      4       1      0
# 70      MfDqmwzf1WxvJFtiRKi4Sg  kgMEBZG6rjkGeFzPaIM4MQ      1       2      1
# ...                        ...                     ...    ...     ...    ...
# 586624  UhsdX5p4AXHCIg6l4ai6Wg  3qZiXA_i4eQ3i4_QXvkhPA      1       1      0
# 586638  TZJzzQsE4R7RmqkVRaLEKw  2rmpfdyV2POqpXtmPHO_IQ      1       0      0
# 586641  R1uYqfaJ9EQ98jaV1PKNIA  I1LP0Vg55lwufnoNREE1KA      1       2      1
# 586646  dvu83QWKsnnbGvNVQ3mv7A  GxuxCctcz3Hyk0wnuly7vQ      4       1      0
# 586656  6YRmtPVvnD_mexQifxAJsg  IkjBNJvMZhea1c3j2H2Ahw      3       0      0
#
#         cool                                               text  \
# 31         0  Ordered Caramel frappe at Drive thru, BIG MIST...
# 45         0  This is the McDonalds closest to my home, but ...
# 46         0  Drum-roll please! Review #100 coming right up!...
# 54         0  We stopped here for my Chai and Hubby's coffee...
# 70         0  I know I shouldn't expect much but everything ...
# ...      ...                                                ...
# 586624     0  I was the only customer standing inside to get...
# 586638     0  always closing drive thru. i've driven here so...
# 586641     1  Horrible service...understaffed....long waits....
# 586646     1  This is now one of two Starbucks in the shoppi...
# 586656     0  Besides it being super busy often, usually, I ...
#
#                       date        name  review_count  \
# 31     2017-12-29 19:38:31   Starbucks            65
# 45     2017-03-27 02:34:49  McDonald's            26
# 46     2014-02-05 19:38:24   Starbucks            33
# 54     2017-02-09 04:35:39   Starbucks            17
# 70     2012-05-28 22:52:18  McDonald's            55
# ...                    ...         ...           ...
# 586624 2021-06-18 23:41:51     Dunkin'            40
# 586638 2021-12-28 18:12:04   Starbucks            27
# 586641 2017-11-13 00:41:49  McDonald's            25
# 586646 2017-01-21 00:19:27   Starbucks            45
# 586656 2022-01-10 12:51:07   Starbucks            31
#
#                                                categories  \
# 31                        Restaurants, Coffee & Tea, Food
# 45      Restaurants, Coffee & Tea, Fast Food, Food, Bu...
# 46                                     Food, Coffee & Tea
# 54                                     Food, Coffee & Tea
# 70      Fast Food, Food, Restaurants, Coffee & Tea, Bu...
# ...                                                   ...
# 586624                         Food, Coffee & Tea, Donuts
# 586638                                 Coffee & Tea, Food
# 586641  Restaurants, Coffee & Tea, Fast Food, Food, Bu...
# 586646                                 Food, Coffee & Tea
# 586656                                 Food, Coffee & Tea
#
#                               address          city state postal_code  \
# 31             2308 Murfreesboro Pike     Nashville    TN       37217
# 45                    9290 E 131st St       Fishers    IN       46038
# 46        13170 North Hazel Dell Pkwy        Carmel    IN       46033
# 54                      5 Hartford Rd  Mount Laurel    NJ       08054
# 70                     914 S Broad St  Philadelphia    PA       19146
# ...                               ...           ...   ...         ...
# 586624  5205 Old Hickory Blvd, Ste110     Hermitage    TN       37076
# 586638               6363 N La Cholla        Tucson    AZ       85741
# 586641               2856 S Claiborne   New Orleans    LA       70125
# 586646                   4811 E Grant        Tucson    AZ       85712
# 586656           2350 South Grand Ave     St. Louis    MO       63104
#
#         stars_3_scale  bow_predicted_sentiment
# 31                  1                        1
# 45                  1                        1
# 46                  3                        3
# 54                  3                        3
# 70                  1                        1
# ...               ...                      ...
# 586624              1                        1
# 586638              1                        1
# 586641              1                        1
# 586646              3                        3
# 586656              2                        3
#
# [50426 rows x 17 columns]
