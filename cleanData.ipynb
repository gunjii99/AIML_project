# %%
#import statements
import pandas as pd
import json
data = []

# %%
#Review.json  - Properties taken : user_id, business_id, stars, useful, funny, cool, text
reviewCols = ['user_id', 'business_id', 'stars', 'useful', 'funny', 'cool', 'text', 'date']

with open('D:\\CBS_MSc_Docs\\Courses\\Sem3\\AIML\\Project\\Yelp-JSON\\Yelp JSON\\yelp_dataset\\yelp_academic_dataset_review.json', encoding='utf-8') as f:
    for line in f:
        record = json.loads(line)
        # Extract only the desired properties
        data.append({col: record.get(col) for col in reviewCols})

df_review = pd.DataFrame(data)

f.close()
data = []

# %%
#df_review

# %%
#Read tip.json - Properties taken : user_id, business_id, text, date

tipCols = ['user_id', 'business_id', 'text', 'date']

with open('D:\\CBS_MSc_Docs\\Courses\\Sem3\\AIML\\Project\\Yelp-JSON\\Yelp JSON\\yelp_dataset\\yelp_academic_dataset_tip.json', encoding='utf-8') as f:
    for line in f:
        record = json.loads(line)
        # Extract only the desired properties
        data.append({col: record.get(col) for col in tipCols})

df_tip = pd.DataFrame(data)

f.close()
data = []

# %%
#df_tip

# %%
df_review = pd.concat([df_review, df_tip], axis=0, ignore_index=True)
df_review
# Out:
#                         user_id             business_id  stars  useful  funny  \
# 0        mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw    3.0     0.0    0.0
# 1        OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ    5.0     1.0    0.0
# 2        8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A    3.0     0.0    0.0
# 3        _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA    5.0     1.0    0.0
# 4        bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ    4.0     1.0    0.0
# ...                         ...                     ...    ...     ...    ...
# 7899190  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ    NaN     NaN    NaN
# 7899191  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g    NaN     NaN    NaN
# 7899192  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ    NaN     NaN    NaN
# 7899193  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ    NaN     NaN    NaN
# 7899194  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ    NaN     NaN    NaN
#
#          cool                                               text  \
# 0         0.0  If you decide to eat here, just be aware it is...
# 1         1.0  I've taken a lot of spin classes over the year...
# 2         0.0  Family diner. Had the buffet. Eclectic assortm...
# 3         1.0  Wow!  Yummy, different,  delicious.   Our favo...
# 4         1.0  Cute interior and owner (?) gave us tour of up...
# ...       ...                                                ...
# 7899190   NaN              Disappointed in one of your managers.
# 7899191   NaN                            Great food and service.
# 7899192   NaN                                Love their Cubans!!
# 7899193   NaN                            Great pizza great price
# 7899194   NaN                  Food is good value but a bit hot!
#
#                         date
# 0        2018-07-07 22:09:11
# 1        2012-01-03 15:28:18
# 2        2014-02-05 20:30:30
# 3        2015-01-04 00:01:03
# 4        2017-01-14 20:54:15
# ...                      ...
# 7899190  2021-09-11 19:18:57
# 7899191  2021-10-30 11:54:36
# 7899192  2021-11-05 13:18:56
# 7899193  2021-11-20 16:11:44
# 7899194  2021-12-07 22:30:00
#
# [7899195 rows x 8 columns]

# %% [markdown]
# Index(['business_id', 'name', 'review_count', 'categories',
#        'attributes.ByAppointmentOnly', 'attributes.BusinessAcceptsCreditCards',
#        'attributes.BikeParking', 'attributes.RestaurantsPriceRange2',
#        'attributes.CoatCheck', 'attributes.RestaurantsTakeOut',
#        'attributes.RestaurantsDelivery', 'attributes.Caters',
#        'attributes.WiFi', 'attributes.BusinessParking',
#        'attributes.WheelchairAccessible', 'attributes.HappyHour',
#        'attributes.OutdoorSeating', 'attributes.HasTV',
#        'attributes.RestaurantsReservations', 'attributes.DogsAllowed',
#        'attributes.Alcohol', 'attributes.GoodForKids',
#        'attributes.RestaurantsAttire', 'attributes.Ambience',
#        'attributes.RestaurantsTableService',
#        'attributes.RestaurantsGoodForGroups', 'attributes.DriveThru',
#        'attributes', 'attributes.NoiseLevel', 'attributes.GoodForMeal',
#        'attributes.BusinessAcceptsBitcoin', 'attributes.Smoking',
#        'attributes.Music', 'attributes.GoodForDancing',
#        'attributes.BestNights', 'attributes.BYOB', 'attributes.Corkage',
#        'attributes.BYOBCorkage', 'attributes.Open24Hours',
#        'attributes.RestaurantsCounterService', 'attributes.AgesAllowed',
#        'attributes.DietaryRestrictions'],
#       dtype='object')

# %%
#Read Business.json

businessCols = ['business_id','name','review_count','categories','address', 'city', 'state', 'postal_code']

with open('D:\\CBS_MSc_Docs\\Courses\\Sem3\\AIML\\Project\\Yelp-JSON\\Yelp JSON\\yelp_dataset\\yelp_academic_dataset_business.json', encoding='utf-8') as f:
    for line in f:
        record = json.loads(line)
        # Extract only the desired properties
        data.append({col: record.get(col) for col in businessCols})

# Flatten the JSON
#df_business = pd.json_normalize(data)

#Remove columns not required
df_business = pd.DataFrame(data)

f.close()
data = []

#df_business.columns

# %%
df_business
# Out:
#                    business_id                      name  review_count  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ             7
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store            15
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target            22
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries            80
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery            13
# ...                        ...                       ...           ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails            13
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited             5
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique             8
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center            24
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink             9
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# ...                                                   ...
# 150341                         Nail Salons, Beauty & Spas
# 150342  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                 address           city state postal_code
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2                  5255 E Broadway Blvd         Tucson    AZ       85711
# 3                           935 Race St   Philadelphia    PA       19107
# 4                         101 Walnut St     Green Lane    PA       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    AB     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    TN       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    IN       46250
# 150344                     2472 Troy Rd   Edwardsville    IL       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    FL       33572
#
# [150346 rows x 8 columns]

# %%
#keep businesses which contains 'Restaurants' as part of category
df_business2 = df_business[df_business["categories"].str.contains("Restaurants|Food", na=False)]
df_business2
# Out:
#                    business_id                           name  review_count  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries            80
# 4       mWMc6_wTdE0EUBKIGXDVfA       Perkiomen Valley Brewery            13
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In             6
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill            19
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In            10
# ...                        ...                            ...           ...
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee            33
# 150328  1jx1sfgjgVg0nM6n3p0xWA           Savaya Coffee Market            41
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant            35
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit            14
# 150340  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House            18
#
#                                                categories  \
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# 5       Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 8       Pubs, Restaurants, Italian, Bars, American (Tr...
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# ...                                                   ...
# 150327  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 150328  Specialty Food, Food, Coffee & Tea, Coffee Roa...
# 150336                               Restaurants, Mexican
# 150339  Restaurants, Comfort Food, Food, Food Trucks, ...
# 150340                        Middle Eastern, Restaurants
#
#                       address          city state postal_code
# 3                 935 Race St  Philadelphia    PA       19107
# 4               101 Walnut St    Green Lane    PA       18054
# 5               615 S Main St  Ashland City    TN       37015
# 8           8025 Mackenzie Rd        Affton    MO       63123
# 9         2312 Dickerson Pike     Nashville    TN       37207
# ...                       ...           ...   ...         ...
# 150327    1181 N Milwaukee St         Boise    ID       83704
# 150328      11177 N Oracle Rd    Oro Valley    AZ       85737
# 150336          1108 S 9th St  Philadelphia    PA       19147
# 150339        4405 Pennell Rd         Aston    DE       19014
# 150340  2470 Guardian Road NW      Edmonton    AB     T5T 1K8
#
# [64616 rows x 8 columns]

# %%
#keep restaurants with reviews more than 100
#df_business2 = df_business2[df_business2["review_count"] >= 50]

#filter out chain restaurants only

# %%
df_business3 = df_business2[df_business2["name"].str.contains("Sonic Drive-In", na=False)]
df_business3
# Out:
#                    business_id            name  review_count  \
# 49541   _jNK0N8pvwTlDJwy7WR7zw  Sonic Drive-In           110
# 76074   5tZJaEsvEDowvbAtL8Jfig  Sonic Drive-In            76
# 97583   twAaV18KPw1vB7NqiOVbEw  Sonic Drive-In            97
# 114809  FdLNzJYoe7U05uQSbK4zsA  Sonic Drive-In            58
# 119486  7H1b6TZ-LNxyGx1cv9suJQ  Sonic Drive-In            64
# 143210  pBZQ1Ckxn_50xrFUSXOxNg  Sonic Drive-In            52
# 146339  SS-UZH6n3FBUBCxx1SRoXA  Sonic Drive-In            50
#
#                                                categories  \
# 49541   Ice Cream & Frozen Yogurt, Burgers, Fast Food,...
# 76074   Burgers, Fast Food, American (Traditional), Fo...
# 97583   Burgers, Ice Cream & Frozen Yogurt, Fast Food,...
# 114809  Ice Cream & Frozen Yogurt, Fast Food, Restaura...
# 119486  Food, Burgers, Fast Food, Restaurants, Dessert...
# 143210  Burgers, Food, Fast Food, Restaurants, Ice Cre...
# 146339  Restaurants, Hot Dogs, Ice Cream & Frozen Yogu...
#
#                             address          city state postal_code
# 49541           1220 Mc Carran Blvd          Reno    NV       89512
# 76074      3156 S Kingshighway Blvd   Saint Louis    MO       63139
# 97583            4995 Galleria Pkwy        Sparks    NV       89436
# 114809    2523 North Dale Mabry Hwy         Tampa    FL       33607
# 119486  3913 Veterans Memorial Blvd      Metairie    LA       70002
# 143210               2405 Easton Rd  WILLOW GROVE    PA       19090
# 146339       1262 North Emerson Ave     Greenwood    IN       46143

# %%
#Dataframe merge ---- mAIN DATASET!!!
#Reviews X Business2df

dataset_df = pd.merge(df_review, df_business2, on="business_id")
dataset_df
# Out:
#                         user_id             business_id  stars  useful  funny  \
# 0        mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw    3.0     0.0    0.0
# 1        _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA    5.0     1.0    0.0
# 2        eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg    1.0     1.0    2.0
# 3        yfFzsLmaWF2d4Sr0UNbBgg  LHSTtnW3YHCeUkRDGyJOyw    5.0     2.0    0.0
# 4        59MxRhNVhU9MYndMkz0wtw  gebiRewfieSdtt17PTW6Zg    3.0     0.0    0.0
# ...                         ...                     ...    ...     ...    ...
# 4890580  5hJR7ljJbhFgOaLi8iz5pQ  AXC__4yZrn-N3BT7-2bV_Q    NaN     NaN    NaN
# 4890581  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g    NaN     NaN    NaN
# 4890582  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ    NaN     NaN    NaN
# 4890583  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ    NaN     NaN    NaN
# 4890584  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ    NaN     NaN    NaN
#
#          cool                                               text  \
# 0         0.0  If you decide to eat here, just be aware it is...
# 1         1.0  Wow!  Yummy, different,  delicious.   Our favo...
# 2         1.0  I am a long term frequent customer of this est...
# 3         0.0  Amazingly amazing wings and homemade bleu chee...
# 4         0.0  Had a party of 6 here for hibachi. Our waitres...
# ...       ...                                                ...
# 4890580   NaN  BOMB food. Super delicious, great outdoor spac...
# 4890581   NaN                            Great food and service.
# 4890582   NaN                                Love their Cubans!!
# 4890583   NaN                            Great pizza great price
# 4890584   NaN                  Food is good value but a bit hot!
#
#                         date                             name  review_count  \
# 0        2018-07-07 22:09:11     Turning Point of North Wales           169
# 1        2015-01-04 00:01:03                            Zaika           181
# 2        2015-09-23 23:10:31                         Dmitri's           273
# 3        2015-08-07 02:29:16                  Fries Rebellion           103
# 4        2016-07-25 07:31:06  Hibachi Steak House & Sushi Bar           488
# ...                      ...                              ...           ...
# 4890580  2021-05-04 21:44:53                       Biergarten           104
# 4890581  2021-10-30 11:54:36                Sus Hi Eatstation            50
# 4890582  2021-11-05 13:18:56               The Strawberry Hut           118
# 4890583  2021-11-20 16:11:44                    Bros Pizzeria           172
# 4890584  2021-12-07 22:30:00                         Cheng Du           132
#
#                                                 categories  \
# 0        Restaurants, Breakfast & Brunch, Food, Juice B...
# 1                    Halal, Pakistani, Restaurants, Indian
# 2               Mediterranean, Restaurants, Seafood, Greek
# 3        Beer Bar, Bars, American (New), Gastropubs, Re...
# 4           Steakhouses, Sushi Bars, Restaurants, Japanese
# ...                                                    ...
# 4890580  Nightlife, Beer Gardens, Restaurants, Pizza, H...
# 4890581                            Restaurants, Sushi Bars
# 4890582                            Restaurants, Sandwiches
# 4890583                        Pizza, Restaurants, Italian
# 4890584                     Restaurants, Szechuan, Chinese
#
#                          address           city state postal_code
# 0            1460 Bethlehem Pike    North Wales    PA       19454
# 1                 2481 Grant Ave   Philadelphia    PA       19114
# 2                   795 S 3rd St   Philadelphia    PA       19147
# 3           1441 S West End Blvd     Quakertown    PA       18951
# 4                   502 State St  Santa Barbara    CA       93101
# ...                          ...            ...   ...         ...
# 4890580            11 Anacapa St  Santa Barbara    CA       93101
# 4890581        2309 E Fowler Ave          Tampa    FL       33612
# 4890582        1505 N Wheeler St     Plant City    FL       33563
# 4890583  547 S Fort Harrison Ave     Clearwater    FL       33756
# 4890584       82 E Lancaster Ave          Paoli    PA       19301
#
# [4890585 rows x 15 columns]

# %%
#checking if merged properly
df_check = dataset_df[dataset_df["name"] == "Zaika"]
df_check

# %%
duplicates = df_check[df_check.duplicated(subset=['user_id'], keep=False)]
#print(duplicates)

#mqBWACmaHflW4eh_Ofp16Q
duplicates = duplicates[duplicates["user_id"].str.contains("mqBWACmaHflW4eh_Ofp16Q")]
print(duplicates[["user_id", "text"]])

# %% [markdown]
# Design choice - do A to C first then the other model
#
# Explain why you chose the model - why and how did you apply this to the business Model
#
# Try using smaller language model 7 million - one - reason - run through more data - more money
#
# Try to use - instructor / response models - consistent and structuired op from llm
#
# future examples and chain of thought
#
# How to train - models that do sentiment already - HuggingFace - roberta - base models
#
# use models like roberta to label it - ideal world you do human and AI annotation
#
# Everywhere where confidence is over 85 - we assume it to be true if less we take a look at the sentiment and correct it.
#
# ensemble models (LAST!!!!) - multiple models running at the same time - more agree more certain - 4 or more models running at the same time
